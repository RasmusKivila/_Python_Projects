# %%
import pandas as pd
df = pd.read_csv('customer_data.csv')
dfov = pd.read_csv('customer_data_only_valid.csv')
dfov.head()
# Out:
#              name          age                              email  \
# 0    Jane Janssen  invalid_age    jane.janssen@distansakademin.se
# 1      Jöe Jensen           28      joe.jensen@distansakademin.se
# 2  Jasper Jacksön           33  jasper.jackson@distansakademin.se
# 3  Jade Jöhanssön           62  jade.johansson@distansakademin.se
# 4      Jill Smith           38      jill.smith@distansakademin.se
#
#          phone purchase_frequency
# 0  0796-306556                low
# 1  0773-523144                low
# 2  0777-580668             medium
# 3  0789-122416                low
# 4  0730-427578               high

# %%
#Information om vår data 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   name                100 non-null    object
#  1   age                 100 non-null    object
#  2   phone               100 non-null    object
#  3   email               100 non-null    object
#  4   purchase_frequency  100 non-null    object
# dtypes: object(5)
# memory usage: 4.0+ KB

# %%
df.describe()
# Out:
#                   name           age          phone  \
# count              100           100            100
# unique              25            40            100
# top     Charlie Rasmus  invalid_mail  078--246711
# freq                 9            15              1
#
#                                     email purchase_frequency
# count                                 100                100
# unique                                 25                  3
# top     charlie.rasmus@distansakademin.se             medium
# freq                                    9                 45

# %%
dfov['purchase_frequency']
# Out:
# 0          low
# 1          low
# 2       medium
# 3          low
# 4         high
#          ...
# 9995    medium
# 9996      high
# 9997      high
# 9998       low
# 9999    medium
# Name: purchase_frequency, Length: 10000, dtype: object

# %%
dfov['purchase_frequency'].value_counts()
# Out:
# low       3369
# medium    3338
# high      3293
# Name: purchase_frequency, dtype: int64

# %%
dfov['age'].value_counts()
# Out:
# invalid_age    1663
# 42              203
# 43              203
# 46              198
# 22              196
# 39              193
# 31              192
# 62              191
# 35              189
# 25              186
# 18              186
# 24              186
# 37              185
# 45              184
# 29              184
# 48              183
# 28              182
# 33              181
# 63              180
# 36              180
# 41              179
# 26              178
# 40              178
# 54              175
# 19              174
# 64              173
# 50              173
# 34              172
# 58              172
# 44              172
# 51              170
# 52              170
# 65              166
# 38              165
# 49              165
# 57              164
# 20              163
# 30              162
# 60              162
# 23              159
# 53              159
# 21              158
# 59              155
# 27              154
# 47              152
# 56              151
# 61              147
# 55              146
# 32              141
# Name: age, dtype: int64

# %%
df.tail()
# Out:
#               name           age          phone  \
# 95  Charlie Rasmus            62  076--623227
# 96     Alice Smith  invalid_mail  074--247854
# 97   Alice Larsson            33  079--956857
# 98  Kivilä Jackson            49  075--629623
# 99  Kivilä Jackson            61  079--971805
#
#                                 email purchase_frequency
# 95  charlie.rasmus@distansakademin.se               high
# 96     alice.smith@distansakademin.se             medium
# 97   alice.larsson@distansakademin.se             medium
# 98  kivilä.jackson@distansakademin.se               high
# 99  kivilä.jackson@distansakademin.se             medium

# %%
df.shape #antal rader[1]antal kolumner[0]
# Out:
# (100, 5)

# %%
df.dtypes
# Out:
# name                  object
# age                   object
# phone                 object
# email                 object
# purchase_frequency    object
# dtype: object

# %%
df.nunique() #alla unika t.ex mail addresser, många delar just nu
# Out:
# name                   25
# age                    40
# phone                 100
# email                  25
# purchase_frequency      3
# dtype: int64

# %%
df.isna().sum() #antal rader med nan värden
# Out:
# name                  0
# age                   0
# phone                 0
# email                 0
# purchase_frequency    0
# dtype: int64

# %%
df[df['email'] == 'invalid_mail']
# Out:
# Empty DataFrame
# Columns: [name, age, phone, email, purchase_frequency]
# Index: []

# %%
df[df['phone'].str.contains('073-')]
# Out:
#                name           age          phone  \
# 2       Alice Smith  invalid_mail  073--553280
# 41      Bob Larsson  invalid_mail  073--340713
# 47    Rafael Rasmus            61  073--922482
# 72  Charlie Larsson            46  073--824554
# 77   Rafael Larsson            19  073--801112
# 80     Alice Becker            22  073--114840
# 84    Rafael Rasmus            64  073--340541
# 86    Charlie Smith            23  073--218820
# 88   Charlie Rasmus  invalid_mail  073--368677
#
#                                  email purchase_frequency
# 2       alice.smith@distansakademin.se               high
# 41      bob.larsson@distansakademin.se               high
# 47    rafael.rasmus@distansakademin.se                low
# 72  charlie.larsson@distansakademin.se             medium
# 77   rafael.larsson@distansakademin.se                low
# 80     alice.becker@distansakademin.se             medium
# 84    rafael.rasmus@distansakademin.se             medium
# 86    charlie.smith@distansakademin.se             medium
# 88   charlie.rasmus@distansakademin.se             medium
