# %%
#Visualisera data

import pandas as pd

df = pd.read_csv("customer_data.csv")
df.head()
# Out:
#               name  age          phone                               email  \
# 0   Charlie Becker   32  076--901931     charlie.becker@distansakademin.se
# 1  Charlie Jackson   21  078--813144    charlie.jackson@distansakademin.se
# 2        Bob Smith   51  072--651048          bob.smith@distansakademin.se
# 3  Alice Alexandre   50  079--812809    alice.alexandre@distansakademin.se
# 4   Rafael Larsson   39  074--613776     rafael.larsson@distansakademin.se
#
#   purchase_frequency
# 0             medium
# 1               high
# 2             medium
# 3                low
# 4               high
