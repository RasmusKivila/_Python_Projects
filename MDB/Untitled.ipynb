# %%
import pandas as pd

df = pd.read_csv("customer_data.csv")

#visa första 5 raderna
df.head()
# Out:
#               name           age          phone  \
# 0  Liselle Jackson            27  074--113555
# 1    Bob Alexandre   invalid_age  077--898407
# 2  Alice Alexandre  invalid_mail  074--577550
# 3   Rafael Larsson            60  071--510207
# 4   Rafael Jackson            45  075--498434
#
#                                 email purchase_frequency
# 0  liselle.jackson@distansakademin.se               high
# 1    bob.alexandre@distansakademin.se                low
# 2  alice.alexandre@distansakademin.se             medium
# 3   rafael.larsson@distansakademin.se               high
# 4   rafael.jackson@distansakademin.se                low
